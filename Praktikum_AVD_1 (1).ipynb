# %% [markdown]
# Link Dataset: https://www.kaggle.com/datasets/adilshamim8/sleep-cycle-and-productivity

# %% [markdown]
# # **Sleep Cycle & Productivity: How Exercise, Cafeine, and Screen Time Affect Sleep Quality**

# %% [markdown]
# ## BUSINESS UNDERSTANDING

# %% [markdown]
# ## Business Objective

# %% [markdown]
# Tujuan proyek ini adalah untuk mengidentifikasi hubungan antara pola tidur dan produktivitas. Hasil dari analisis ini dapat digunakan untuk memberikan rekomendasi waktu kerja yang cukup dengan memperhatikan waktu tidur dalam meningkatkan kesejahteraan suatu individu.

# %% [markdown]
# ## Assess Situation

# %% [markdown]
# Situasi bisnis yang mendasari analisis ini adalah meningkatnya kesadaran akan pentingnya kualitas tidur dalam meningkatkan produktivitas individu. Tekanan kerja, pola hidup yang tidak sehat, serta kebiasaan tidur yang buruk dapat memengaruhi kinerja dari individu tersebut di suatu organisasi.

# %% [markdown]
# ## Data Mining Goals

# %% [markdown]
# Mengidentifikasi hubungan antara kebiasaan tidur dan produktivitas dengan menganalisis beberapa faktor, seperti durasi tidur dan kualitas tidur. Dengan memahami polanya, diharapkan dapat mencari strategi dalam meningkatkan keseimbangan kerja dan istirahat.

# %% [markdown]
# ## Project Plan

# %% [markdown]
# 1.   Mencari dan memahami isi dataset
# 2.   Mengatasi data yang nilainya hilang, tidak valid, atau anomali di dataset tersebut
# 3. Visualisasikan data untuk mengidentifikasi pola
# 4. Memberikan saran atau rekomendasi kepada perusahaan mengenai strategi dari hasil analisis tersebut
# 5.Menerapkannya ke perusahaan dan individu serta memantau dalam jangka waktu tertentu untuk mengukur seberapa berhasil strategi tersebut

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df
# Out:
#             Date  Person_ID  Age  Gender  Sleep Start Time  Sleep End Time  \
# 0     2024-04-12       1860   32   Other             23.33            4.61
# 1     2024-11-04       1769   41  Female             21.02            2.43
# 2     2024-08-31       2528   20    Male             22.10            3.45
# 3     2024-02-22       8041   37   Other             23.10            6.65
# 4     2024-02-23       4843   46   Other             21.42            4.17
# ...          ...        ...  ...     ...               ...             ...
# 4995  2024-01-03       5192   38  Female             22.78            4.15
# 4996  2024-06-02       7134   55    Male             21.48            5.39
# 4997  2024-08-13       6265   44  Female             22.02            2.82
# 4998  2024-12-26       4205   55   Other             23.47            7.87
# 4999  2024-04-11       2304   58    Male             20.72            1.37
#
#       Total Sleep Hours  Sleep Quality  Exercise (mins/day)  \
# 0                  5.28              3                   86
# 1                  5.41              5                   32
# 2                  5.35              7                   17
# 3                  7.55              8                   46
# 4                  6.75             10                   61
# ...                 ...            ...                  ...
# 4995               5.37              1                   55
# 4996               7.91              4                   70
# 4997               4.80              6                   21
# 4998               8.40              9                   15
# 4999               4.65              1                    6
#
#       Caffeine Intake (mg)  Screen Time Before Bed (mins)  \
# 0                       87                            116
# 1                       21                             88
# 2                       88                             59
# 3                       34                             80
# 4                      269                             94
# ...                    ...                            ...
# 4995                   216                             96
# 4996                    81                            177
# 4997                    90                            139
# 4998                    87                            161
# 4999                    26                             35
#
#       Work Hours (hrs/day)  Productivity Score  Mood Score  Stress Level
# 0                 8.808920                   8           3             6
# 1                 6.329833                  10           3             7
# 2                 8.506306                  10           9            10
# 3                 6.070240                   8           4             2
# 4                11.374994                   8           7             9
# ...                    ...                 ...         ...           ...
# 4995              9.384504                   5           2             1
# 4996              5.016193                   5           6             2
# 4997             11.788651                   2           7             1
# 4998              7.093145                   8           1             6
# 4999              5.615948                   6           9             4
#
# [5000 rows x 15 columns]

# %%
import pandas as pd

# %%
file_path = "/content/sleep_cycle_productivity.csv"

df = pd.read_csv(file_path)

# %% [markdown]
# # Pengecekan Struktur Data

# %%
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a29405eb924b> in <cell line: 0>()
# ----> 1 df.head(5)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Ringkasan singkat dataset

# %%
df.head()
# Out:
#          Date  Person_ID  Age  Gender  Sleep Start Time  Sleep End Time  \
# 0  2024-04-12       1860   32   Other             23.33            4.61
# 1  2024-11-04       1769   41  Female             21.02            2.43
# 2  2024-08-31       2528   20    Male             22.10            3.45
# 3  2024-02-22       8041   37   Other             23.10            6.65
# 4  2024-02-23       4843   46   Other             21.42            4.17
#
#    Total Sleep Hours  Sleep Quality  Exercise (mins/day)  \
# 0               5.28              3                   86
# 1               5.41              5                   32
# 2               5.35              7                   17
# 3               7.55              8                   46
# 4               6.75             10                   61
#
#    Caffeine Intake (mg)  Screen Time Before Bed (mins)  Work Hours (hrs/day)  \
# 0                    87                            116              8.808920
# 1                    21                             88              6.329833
# 2                    88                             59              8.506306
# 3                    34                             80              6.070240
# 4                   269                             94             11.374994
#
#    Productivity Score  Mood Score  Stress Level
# 0                   8           3             6
# 1                  10           3             7
# 2                  10           9            10
# 3                   8           4             2
# 4                   8           7             9

# %%
df.tail()
# Out:
#             Date  Person_ID  Age  Gender  Sleep Start Time  Sleep End Time  \
# 4995  2024-01-03       5192   38  Female             22.78            4.15
# 4996  2024-06-02       7134   55    Male             21.48            5.39
# 4997  2024-08-13       6265   44  Female             22.02            2.82
# 4998  2024-12-26       4205   55   Other             23.47            7.87
# 4999  2024-04-11       2304   58    Male             20.72            1.37
#
#       Total Sleep Hours  Sleep Quality  Exercise (mins/day)  \
# 4995               5.37              1                   55
# 4996               7.91              4                   70
# 4997               4.80              6                   21
# 4998               8.40              9                   15
# 4999               4.65              1                    6
#
#       Caffeine Intake (mg)  Screen Time Before Bed (mins)  \
# 4995                   216                             96
# 4996                    81                            177
# 4997                    90                            139
# 4998                    87                            161
# 4999                    26                             35
#
#       Work Hours (hrs/day)  Productivity Score  Mood Score  Stress Level
# 4995              9.384504                   5           2             1
# 4996              5.016193                   5           6             2
# 4997             11.788651                   2           7             1
# 4998              7.093145                   8           1             6
# 4999              5.615948                   6           9             4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date                           5000 non-null   object
#  1   Person_ID                      5000 non-null   int64
#  2   Age                            5000 non-null   int64
#  3   Gender                         5000 non-null   object
#  4   Sleep Start Time               5000 non-null   float64
#  5   Sleep End Time                 5000 non-null   float64
#  6   Total Sleep Hours              5000 non-null   float64
#  7   Sleep Quality                  5000 non-null   int64
#  8   Exercise (mins/day)            5000 non-null   int64
#  9   Caffeine Intake (mg)           5000 non-null   int64
#  10  Screen Time Before Bed (mins)  5000 non-null   int64
#  11  Work Hours (hrs/day)           5000 non-null   float64
#  12  Productivity Score             5000 non-null   int64
#  13  Mood Score                     5000 non-null   int64
#  14  Stress Level                   5000 non-null   int64
# dtypes: float64(4), int64(9), object(2)
# memory usage: 586.1+ KB

# %% [markdown]
# ## Total baris dan kolom

# %%
df.shape
# Out:
# (5000, 15)

# %% [markdown]
# ## Tipe data

# %%
df.dtypes
# Out:
# Date                              object
# Person_ID                          int64
# Age                                int64
# Gender                            object
# Sleep Start Time                 float64
# Sleep End Time                   float64
# Total Sleep Hours                float64
# Sleep Quality                      int64
# Exercise (mins/day)                int64
# Caffeine Intake (mg)               int64
# Screen Time Before Bed (mins)      int64
# Work Hours (hrs/day)             float64
# Productivity Score                 int64
# Mood Score                         int64
# Stress Level                       int64
# dtype: object

# %% [markdown]
# # Statistik Deskriptif

# %% [markdown]
# ## Mean, median min, max, dan kuartil

# %%
df.describe()
# Out:
#          Person_ID          Age  Sleep Start Time  Sleep End Time  \
# count  5000.000000  5000.000000       5000.000000     5000.000000
# mean   5527.152200    38.590600         22.005350        4.980262
# std    2595.391771    12.302799          1.157591        1.862508
# min    1000.000000    18.000000         20.000000        0.560000
# 25%    3258.000000    28.000000         21.020000        3.660000
# 50%    5603.000000    39.000000         22.020000        4.970000
# 75%    7749.500000    49.000000         23.000000        6.310000
# max    9998.000000    59.000000         23.980000        9.420000
#
#        Total Sleep Hours  Sleep Quality  Exercise (mins/day)  \
# count        5000.000000    5000.000000          5000.000000
# mean            6.974902       5.520800            43.962600
# std             1.454033       2.863845            25.798541
# min             4.500000       1.000000             0.000000
# 25%             5.690000       3.000000            22.000000
# 50%             6.960000       5.000000            44.000000
# 75%             8.210000       8.000000            66.000000
# max             9.500000      10.000000            89.000000
#
#        Caffeine Intake (mg)  Screen Time Before Bed (mins)  \
# count            5000.00000                    5000.000000
# mean              146.71140                      91.421200
# std                85.83139                      52.079123
# min                 0.00000                       0.000000
# 25%                73.00000                      46.000000
# 50%               144.00000                      92.000000
# 75%               220.00000                     136.000000
# max               299.00000                     179.000000
#
#        Work Hours (hrs/day)  Productivity Score   Mood Score  Stress Level
# count           5000.000000         5000.000000  5000.000000   5000.000000
# mean               7.987873            5.644200     5.370600      5.548000
# std                2.275734            2.872221     2.835783      2.888419
# min                4.000067            1.000000     1.000000      1.000000
# 25%                6.032720            3.000000     3.000000      3.000000
# 50%                7.998295            6.000000     5.000000      6.000000
# 75%                9.905024            8.000000     8.000000      8.000000
# max               11.999141           10.000000    10.000000     10.000000

# %% [markdown]
# ## Menghitung Munculnya Nilai Unik

# %%
df.value_counts()
# Out:
# Date        Person_ID  Age  Gender  Sleep Start Time  Sleep End Time  Total Sleep Hours  Sleep Quality  Exercise (mins/day)  Caffeine Intake (mg)  Screen Time Before Bed (mins)  Work Hours (hrs/day)  Productivity Score  Mood Score  Stress Level
# 2024-01-01  3302       50   Female  22.03             5.86            7.83               6              87                   176                   99                             6.354715              10                  1           3               1
# 2024-09-02  6232       59   Female  20.22             0.98            4.77               2              26                   54                    119                            11.533536             5                   5           7               1
#             8542       41   Female  21.15             4.27            7.12               7              57                   14                    7                              8.297855              7                   3           3               1
#             8540       45   Female  20.02             3.51            7.49               2              45                   159                   124                            6.360485              3                   6           9               1
#             7834       33   Other   22.37             7.08            8.71               5              51                   194                   123                            9.939426              6                   6           2               1
#                                                                                                                                                                                                                                                        ..
# 2024-05-05  2031       41   Female  23.28             6.56            7.27               4              69                   17                    55                             6.924230              6                   6           10              1
#             1948       38   Male    23.50             4.87            5.37               2              14                   137                   47                             9.879972              6                   10          7               1
#             1532       22   Other   23.52             7.34            7.82               3              69                   82                    167                            7.104725              7                   3           7               1
#             1081       57   Other   22.88             5.49            6.60               8              49                   17                    140                            9.922907              6                   6           6               1
# 2024-12-31  9970       19   Male    20.67             1.41            4.74               8              53                   158                   52                             6.550575              9                   10          4               1
# Name: count, Length: 5000, dtype: int64

# %% [markdown]
# ## Mean

# %%
df.mean(numeric_only=True)
# Out:
# Person_ID                        5527.152200
# Age                                38.590600
# Sleep Start Time                   22.005350
# Sleep End Time                      4.980262
# Total Sleep Hours                   6.974902
# Sleep Quality                       5.520800
# Exercise (mins/day)                43.962600
# Caffeine Intake (mg)              146.711400
# Screen Time Before Bed (mins)      91.421200
# Work Hours (hrs/day)                7.987873
# Productivity Score                  5.644200
# Mood Score                          5.370600
# Stress Level                        5.548000
# dtype: float64

# %% [markdown]
# ## Median

# %%
df.median(numeric_only=True)
# Out:
# Person_ID                        5603.000000
# Age                                39.000000
# Sleep Start Time                   22.020000
# Sleep End Time                      4.970000
# Total Sleep Hours                   6.960000
# Sleep Quality                       5.000000
# Exercise (mins/day)                44.000000
# Caffeine Intake (mg)              144.000000
# Screen Time Before Bed (mins)      92.000000
# Work Hours (hrs/day)                7.998295
# Productivity Score                  6.000000
# Mood Score                          5.000000
# Stress Level                        6.000000
# dtype: float64

# %% [markdown]
# ## Standar Deviasi

# %%
df.std(numeric_only=True)
# Out:
# Person_ID                        2595.391771
# Age                                12.302799
# Sleep Start Time                    1.157591
# Sleep End Time                      1.862508
# Total Sleep Hours                   1.454033
# Sleep Quality                       2.863845
# Exercise (mins/day)                25.798541
# Caffeine Intake (mg)               85.831390
# Screen Time Before Bed (mins)      52.079123
# Work Hours (hrs/day)                2.275734
# Productivity Score                  2.872221
# Mood Score                          2.835783
# Stress Level                        2.888419
# dtype: float64

# %% [markdown]
# ## Analisis Korelasi

# %%
df.corr(numeric_only=True)
# Out:
#                                Person_ID       Age  Sleep Start Time  \
# Person_ID                       1.000000 -0.022157         -0.006961
# Age                            -0.022157  1.000000         -0.000317
# Sleep Start Time               -0.006961 -0.000317          1.000000
# Sleep End Time                 -0.001408 -0.008909          0.624997
# Total Sleep Hours               0.003795 -0.011092          0.004382
# Sleep Quality                   0.001143 -0.006160          0.001317
# Exercise (mins/day)             0.008450  0.009525          0.015982
# Caffeine Intake (mg)            0.009354 -0.001473         -0.003353
# Screen Time Before Bed (mins)  -0.024392 -0.008662          0.005332
# Work Hours (hrs/day)            0.009269  0.007713          0.013158
# Productivity Score              0.012437 -0.008369          0.011774
# Mood Score                      0.014973 -0.000295         -0.017617
# Stress Level                    0.001177 -0.024990          0.031956
#
#                                Sleep End Time  Total Sleep Hours  \
# Person_ID                           -0.001408           0.003795
# Age                                 -0.008909          -0.011092
# Sleep Start Time                     0.624997           0.004382
# Sleep End Time                       1.000000           0.783354
# Total Sleep Hours                    0.783354           1.000000
# Sleep Quality                        0.002731           0.002390
# Exercise (mins/day)                  0.023624           0.017514
# Caffeine Intake (mg)                 0.013747           0.020274
# Screen Time Before Bed (mins)        0.007771           0.005732
# Work Hours (hrs/day)                -0.009755          -0.022910
# Productivity Score                   0.022031           0.018885
# Mood Score                          -0.016487          -0.007092
# Stress Level                         0.016709          -0.004082
#
#                                Sleep Quality  Exercise (mins/day)  \
# Person_ID                           0.001143             0.008450
# Age                                -0.006160             0.009525
# Sleep Start Time                    0.001317             0.015982
# Sleep End Time                      0.002731             0.023624
# Total Sleep Hours                   0.002390             0.017514
# Sleep Quality                       1.000000             0.000570
# Exercise (mins/day)                 0.000570             1.000000
# Caffeine Intake (mg)                0.000669             0.015268
# Screen Time Before Bed (mins)       0.002062            -0.005794
# Work Hours (hrs/day)               -0.014777            -0.000429
# Productivity Score                 -0.001155            -0.024903
# Mood Score                          0.005812            -0.012675
# Stress Level                       -0.014364            -0.012240
#
#                                Caffeine Intake (mg)  \
# Person_ID                                  0.009354
# Age                                       -0.001473
# Sleep Start Time                          -0.003353
# Sleep End Time                             0.013747
# Total Sleep Hours                          0.020274
# Sleep Quality                              0.000669
# Exercise (mins/day)                        0.015268
# Caffeine Intake (mg)                       1.000000
# Screen Time Before Bed (mins)              0.009154
# Work Hours (hrs/day)                       0.000893
# Productivity Score                         0.005058
# Mood Score                                 0.002703
# Stress Level                               0.009030
#
#                                Screen Time Before Bed (mins)  \
# Person_ID                                          -0.024392
# Age                                                -0.008662
# Sleep Start Time                                    0.005332
# Sleep End Time                                      0.007771
# Total Sleep Hours                                   0.005732
# Sleep Quality                                       0.002062
# Exercise (mins/day)                                -0.005794
# Caffeine Intake (mg)                                0.009154
# Screen Time Before Bed (mins)                       1.000000
# Work Hours (hrs/day)                                0.005476
# Productivity Score                                  0.003703
# Mood Score                                          0.003839
# Stress Level                                       -0.000814
#
#                                Work Hours (hrs/day)  Productivity Score  \
# Person_ID                                  0.009269            0.012437
# Age                                        0.007713           -0.008369
# Sleep Start Time                           0.013158            0.011774
# Sleep End Time                            -0.009755            0.022031
# Total Sleep Hours                         -0.022910            0.018885
# Sleep Quality                             -0.014777           -0.001155
# Exercise (mins/day)                       -0.000429           -0.024903
# Caffeine Intake (mg)                       0.000893            0.005058
# Screen Time Before Bed (mins)              0.005476            0.003703
# Work Hours (hrs/day)                       1.000000           -0.016263
# Productivity Score                        -0.016263            1.000000
# Mood Score                                 0.023793           -0.006673
# Stress Level                               0.013442           -0.001088
#
#                                Mood Score  Stress Level
# Person_ID                        0.014973      0.001177
# Age                             -0.000295     -0.024990
# Sleep Start Time                -0.017617      0.031956
# Sleep End Time                  -0.016487      0.016709
# Total Sleep Hours               -0.007092     -0.004082
# Sleep Quality                    0.005812     -0.014364
# Exercise (mins/day)             -0.012675     -0.012240
# Caffeine Intake (mg)             0.002703      0.009030
# Screen Time Before Bed (mins)    0.003839     -0.000814
# Work Hours (hrs/day)             0.023793      0.013442
# Productivity Score              -0.006673     -0.001088
# Mood Score                       1.000000      0.004287
# Stress Level                     0.004287      1.000000
